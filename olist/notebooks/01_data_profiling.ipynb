# %%
import pandas as pd
from fg_data_profiling import ProfileReport
# Out:
# Running cells with 'ML_projeto_SENAI (3.14.6) (Python 3.14.6)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/1T1.891222/Downloads/ML_projeto_SENAI/ML_projeto_SENAI/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
arquivo = "ML_projeto_SENAI\olist\data\raw\Brazilian E-Commerce Public Dataset by Olist\olist_order_dataset.csv"

df = pd.read_csv(arquivo)
profile = ProfileReport(df, title="Profiling Report")
profile.to_file("report.html")
# Out:
# Running cells with 'ML_projeto_SENAI (3.14.6) (Python 3.14.6)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/1T1.891222/Downloads/ML_projeto_SENAI/ML_projeto_SENAI/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
