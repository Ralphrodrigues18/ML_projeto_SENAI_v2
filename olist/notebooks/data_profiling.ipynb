# %%
import pandas as pd
import pkg_resources
from ydata_profiling import ProfileReport

df = pd.read_csv(pkg_resources.resource_filename("olist", "data/raw/olist_orders_dataset.csv"))
# Out:
# Matplotlib is building the font cache; this may take a moment.
# C:\Users\1T1.891222\AppData\Local\Temp\ipykernel_17616\1224096041.py:3: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please install fg-data-profiling via `pip install fg-data-profiling` and use `import data_profiling` instead.
#
#   from ydata_profiling import ProfileReport

# %%
df = pd.read_csv(pkg_resources.resource_filename("olist", "data/raw/olist_orders_dataset.csv"))
profile = ProfileReport(df, title="Pandas Profiling Report", explorative=True)

profile
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Downloads\ML_projeto_SENAI\ML_projeto_SENAI\olist\.venv\Lib\site-packages\pkg_resources\__init__.py:421, in get_provider(moduleOrReq)
#     420 try:
# --> 421     module = sys.modules[moduleOrReq]
#     422 except KeyError:
#
# KeyError: 'olist'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df = pd.read_csv(pkg_resources.resource_filename("olist", "data/raw/olist_orders_dataset.csv"))
#       2 profile = ProfileReport(df, title="Pandas Profiling Report", explorative=True)
#       3
#       4 profile
#
# ...
